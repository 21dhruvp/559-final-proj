# %% [markdown]
# # Clustering

# %%
import numpy as np
from sklearn.cluster import KMeans

# %%
import pandas as pd

df = pd.read_csv('train_data.csv').drop(columns=['Index'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5807 entries, 0 to 5806
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 5807 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  5807 non-null   float64
#  2    ROA(A) before interest and % after tax                   5807 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        5807 non-null   float64
#  4    Operating Gross Margin                                   5807 non-null   float64
#  5    Realized Sales Gross Margin                              5807 non-null   float64
#  6    Operating Profit Rate                                    5807 non-null   float64
#  7    Pre-tax net Interest Rate                                5807 non-null   float64
# ...

# %%
# 4 team members = 4 clusters
n_clust = 4 
km = KMeans(n_clusters=n_clust, random_state=67)

out_cl = km.fit_predict(X=df, y=None)

# %%
# Partition the data into separate dataframes based on cluster labels in out_cl
for i in range(n_clust):
    curr_cl_data = df[out_cl == i]
    print(f"cluster {i}")
    print(curr_cl_data.info())
    curr_cl_data.to_csv(f'cluster{i}.csv')
# Out:
# cluster 0
# <class 'pandas.core.frame.DataFrame'>
# Index: 921 entries, 3 to 5797
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 921 non-null    int64
#  1    ROA(C) before interest and depreciation before interest  921 non-null    float64
#  2    ROA(A) before interest and % after tax                   921 non-null    float64
#  3    ROA(B) before interest and depreciation after tax        921 non-null    float64
#  4    Operating Gross Margin                                   921 non-null    float64
#  5    Realized Sales Gross Margin                              921 non-null    float64
#  6    Operating Profit Rate                                    921 non-null    float64
# ...
